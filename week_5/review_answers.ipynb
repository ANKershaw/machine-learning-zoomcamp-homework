# %% [markdown]
# ## Pickle
#
# 1. save
# 2. with open('model.bin', 'wb') as f_out: and with open('model.bin', 'rb' as f_in: to ensure we close the file when we're done
# 3. pickle.dump((dv, model), f_out)
# 4. pickle.load(f_in)
#
#
# ## Pipeline
#
# 1. from sklearn.pipeline import make_pipeline
# 2. to combine the steps of DictVectorizer() and LogisticRegression() and to only have to pickle one thing
# 3.
