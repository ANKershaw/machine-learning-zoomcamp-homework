# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeRegressor, export_text
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Homework
#
# > Note: sometimes your answer doesn't match one of
# > the options exactly. That's fine.
# > Select the option that's closest to your solution.
# > If it's exactly in between two options, select the higher value.
#
#
# ### Dataset
#
# In this homework, we continue using the fuel efficiency dataset.
# Download it from <a href='https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv'>here</a>.
#
# You can do it with wget:
#
# ```bash
# wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# ```
#
# The goal of this homework is to create a regression model for predicting the car fuel efficiency (column `'fuel_efficiency_mpg'`).

# %%
data = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')
data.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %% [markdown]
# ### Preparing the dataset
#
# Preparation:
#
# * Fill missing values with zeros.
# * Do train/validation/test split with 60%/20%/20% distribution.
# * Use the `train_test_split` function and set the `random_state` parameter to 1.
# * Use `DictVectorizer(sparse=True)` to turn the dataframes into matrices.

# %%
data.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
data.fillna(0, inplace=True)
data.isna().sum()
# Out:
# engine_displacement    0
# num_cylinders          0
# horsepower             0
# vehicle_weight         0
# acceleration           0
# model_year             0
# origin                 0
# fuel_type              0
# drivetrain             0
# num_doors              0
# fuel_efficiency_mpg    0
# dtype: int64

# %%
df_full_train, df_test = train_test_split(data, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
y_train = df_train['fuel_efficiency_mpg'].values
y_val = df_val['fuel_efficiency_mpg'].values
y_test = df_test['fuel_efficiency_mpg'].values

x_train = df_train.drop('fuel_efficiency_mpg', axis=1).reset_index(drop=True)
x_val = df_val.drop('fuel_efficiency_mpg', axis=1).reset_index(drop=True)
x_test = df_test.drop('fuel_efficiency_mpg', axis=1).reset_index(drop=True)

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(x_train.to_dict(orient='records'))
X_val = dv.transform(x_val.to_dict(orient='records'))
X_test = dv.transform(x_test.to_dict(orient='records'))

# %% [markdown]
# ## Question 1
#
# Let's train a decision tree regressor to predict the `fuel_efficiency_mpg` variable.
#
# * Train a model with `max_depth=1`.
#
#
# Which feature is used for splitting the data?
#
#
# * `'vehicle_weight'`
# * `'model_year'`
# * `'origin'`
# * `'fuel_type'`

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'engine_displacement',
#        'fuel_type=Diesel', 'fuel_type=Gasoline', 'horsepower',
#        'model_year', 'num_cylinders', 'num_doors', 'origin=Asia',
#        'origin=Europe', 'origin=USA', 'vehicle_weight'], dtype=object)

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
y_pred = dt.predict(X_val)

# %%
export_text(dt, feature_names=dv.get_feature_names_out())
# Out:
# '|--- vehicle_weight <= 3022.11\n|   |--- value: [16.88]\n|--- vehicle_weight >  3022.11\n|   |--- value: [12.94]\n'

# %% [markdown]
# ## Question 2
#
# Train a random forest regressor with these parameters:
#
# * `n_estimators=10`
# * `random_state=1`
# * `n_jobs=-1` (optional - to make training faster)
#
#
# What's the RMSE of this model on the validation data?
#
# * 0.045
# * 0.45 <-
# * 4.5
# * 45.0

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
y_pred = rf.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 0.4570712602619733

# %% [markdown]
# ## Question 3
#
# Now let's experiment with the `n_estimators` parameter
#
# * Try different values of this parameter from 10 to 200 with step 10.
# * Set `random_state` to `1`.
# * Evaluate the model on the validation dataset.
#
#
# After which value of `n_estimators` does RMSE stop improving?
# Consider 3 decimal places for calculating the answer.
#
# - 10 <-
# - 25
# - 80
# - 200
#
# If it doesn't stop improving, use the latest iteration number in
# your answer.

# %%
estimators_range = np.arange(10, 201, 10)
rmse_values = []

for r in estimators_range:
    rf = RandomForestRegressor(n_estimators=r, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_val)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    rmse_values.append((r, round(rmse,3)))
# Out:
# RandomForestRegressor(n_estimators=np.int64(10), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(20), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(30), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(40), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(50), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(60), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(70), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(80), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(90), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(100), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(110), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(120), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(130), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(140), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(150), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(160), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(170), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(180), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(190), n_jobs=-1, random_state=1)
# RandomForestRegressor(n_estimators=np.int64(200), n_jobs=-1, random_state=1)

# %%
rmse_values
# Out:
# [(np.int64(10), np.float64(0.457)),
#  (np.int64(20), np.float64(0.452)),
#  (np.int64(30), np.float64(0.45)),
#  (np.int64(40), np.float64(0.448)),
#  (np.int64(50), np.float64(0.446)),
#  (np.int64(60), np.float64(0.445)),
#  (np.int64(70), np.float64(0.445)),
#  (np.int64(80), np.float64(0.445)),
#  (np.int64(90), np.float64(0.444)),
#  (np.int64(100), np.float64(0.444)),
#  (np.int64(110), np.float64(0.443)),
#  (np.int64(120), np.float64(0.443)),
#  (np.int64(130), np.float64(0.443)),
#  (np.int64(140), np.float64(0.443)),
#  (np.int64(150), np.float64(0.442)),
#  (np.int64(160), np.float64(0.442)),
#  (np.int64(170), np.float64(0.442)),
#  (np.int64(180), np.float64(0.442)),
#  (np.int64(190), np.float64(0.442)),
#  (np.int64(200), np.float64(0.442))]

# %% [markdown]
# ## Question 4
#
# Let's select the best `max_depth`:
#
# * Try different values of `max_depth`: `[10, 15, 20, 25]`
# * For each of these values,
#   * try different values of `n_estimators` from 10 till 200 (with step 10)
#   * calculate the mean RMSE
# * Fix the random seed: `random_state=1`
#
#
# What's the best `max_depth`, using the mean RMSE?
#
# * 10
# * 15
# * 20 <-
# * 25

# %%
rmse_results = []

for max_depth in [10, 15, 20, 25]:
    rmse_values = []
    for n_estimators in estimators_range:
        rf = RandomForestRegressor(n_estimators=n_estimators, random_state=1, n_jobs=-1, max_depth=max_depth)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        rmse_values.append(rmse)

    rmse_results.append((max_depth, np.mean(rmse_values)))

rmse_results
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(10), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(20), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(30), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(40), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(50), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(60), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(70), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(80), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(90), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(100), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(110), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(120), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(130), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(140), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(150), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(160), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(170), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(180), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(190), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=10, n_estimators=np.int64(200), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(10), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(20), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(30), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(40), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(50), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(60), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(70), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(80), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(90), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(100), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(110), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(120), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(130), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(140), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(150), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(160), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(170), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(180), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(190), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=15, n_estimators=np.int64(200), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(10), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(20), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(30), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(40), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(50), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(60), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(70), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(80), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(90), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(100), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(110), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(120), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(130), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(140), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(150), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(160), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(170), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(180), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(190), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=20, n_estimators=np.int64(200), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(10), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(20), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(30), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(40), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(50), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(60), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(70), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(80), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(90), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(100), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(110), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(120), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(130), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(140), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(150), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(160), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(170), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(180), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(190), n_jobs=-1,
#                       random_state=1)
# RandomForestRegressor(max_depth=25, n_estimators=np.int64(200), n_jobs=-1,
#                       random_state=1)
# [(10, np.float64(0.44177370392969184)),
#  (15, np.float64(0.4450240433962002)),
#  (20, np.float64(0.4459547840883615)),
#  (25, np.float64(0.4454084664373769))]

# %% [markdown]
# # Question 5
#
# We can extract feature importance information from tree-based models.
#
# At each step of the decision tree learning algorithm, it finds the best split.
# When doing it, we can calculate "gain" - the reduction in impurity before and after the split.
# This gain is quite useful in understanding what are the important features for tree-based models.
#
# In Scikit-Learn, tree-based models contain this information in the
# [`feature_importances_`](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor.feature_importances_)
# field.
#
# For this homework question, we'll find the most important feature:
#
# * Train the model with these parameters:
#   * `n_estimators=10`,
#   * `max_depth=20`,
#   * `random_state=1`,
#   * `n_jobs=-1` (optional)
# * Get the feature importance information from this model
#
#
# What's the most important feature (among these 4)?
#
# * `vehicle_weight` <-
# *	`horsepower`
# * `acceleration`
# * `engine_displacement`

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1, max_depth=20)
rf.fit(X_train, y_train)
df = pd.DataFrame(dv.get_feature_names_out(), rf.feature_importances_)
df
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=10, n_jobs=-1, random_state=1)
#                                      0
# 0.011454                  acceleration
# 0.000397    drivetrain=All-wheel drive
# 0.000311  drivetrain=Front-wheel drive
# 0.003282           engine_displacement
# 0.000369              fuel_type=Diesel
# 0.000302            fuel_type=Gasoline
# 0.016042                    horsepower
# 0.003165                    model_year
# 0.002331                 num_cylinders
# 0.001628                     num_doors
# 0.000485                   origin=Asia
# 0.000494                 origin=Europe
# 0.000565                    origin=USA
# 0.959176                vehicle_weight

# %% [markdown]
# ## Question 6
#
# Now let's train an XGBoost model! For this question, we'll tune the `eta` parameter:
#
# * Install XGBoost
# * Create DMatrix for train and validation
# * Create a watchlist
# * Train a model with these parameters for 100 rounds:
#
# ```
# xgb_params = {
#     'eta': 0.3,
#     'max_depth': 6,
#     'min_child_weight': 1,
#
#     'objective': 'reg:squarederror',
#     'nthread': 8,
#
#     'seed': 1,
#     'verbosity': 1,
# }
# ```
#
# Now change `eta` from `0.3` to `0.1`.
#
# Which eta leads to the best RMSE score on the validation dataset?
#
# * 0.3 <-
# * 0.1
# * Both give equal value

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=dv.get_feature_names_out().tolist())
dval = xgb.DMatrix(X_val, label=y_val, feature_names=dv.get_feature_names_out().tolist())

# %%
xgb_params = {
    'eta': 0.3, # learning rate
    'max_depth': 6, # size of trees
    'min_child_weight': 1, # mean sample

    'objective': 'reg:squarederror',
    'nthread': 8, # how many threads

    'seed': 1, # to reproduce
    'verbosity': 1, # warnings: show
}

# %%
model = xgb.train(params=xgb_params, dtrain=dtrain, num_boost_round=100)
y_pred = model.predict(dval)

# %%
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
print(f"eta: {xgb_params['eta']}, rmse: {rmse}" )

xgb_params['eta'] = 0.1
model = xgb.train(params=xgb_params, dtrain=dtrain, num_boost_round=100)
y_pred = model.predict(dval)
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
print(f"eta: {xgb_params['eta']}, rmse: {rmse}" )
# Out:
# eta: 0.3, rmse: 0.45017755678087246
# eta: 0.1, rmse: 0.42622800553359225

# %% [markdown]
# ## Submit the results
#
# * Submit your results here: https://courses.datatalks.club/ml-zoomcamp-2025/homework/hw06
# * If your answer doesn't match options exactly, select the closest one. If the answer is exactly in between two options, select the higher value.
