# %% [markdown]
# ## Decision Trees
#
# 1. Trees consist of conditions with ____ and _____ branches off of these conditions.
# 2. How do you import the decision tree classifier
# 3. If a decision tree grows too deep, the model will _____ the data
# 4. Parameter tuning for decision trees involves selecting _______ and ________
#
# ## Random Forest
#
# 1. Describe the relationship between decision trees and random forests
# 2. How do you import the random forest classifier?
# 3. Parameter tuning for random forests involves selecting _______, _________, and ________
