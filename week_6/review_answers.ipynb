# %% [markdown]
# ## Decision Trees
#
# 1. True False
# 2. from sklearn.tree import DecisionTreeClassifier
# 3. Overfit
# 4. max_depth and min_samples_leaf (controls the size of the leaf)
#
# ## Random Forest
#
# 1. A random forest is an ML algorithm made up of decision trees. It is a way to improve accuracy and reduce overfitting. Multiple trees are built and averaged to provide a result.
# 2. from sklearn.ensemble import RandomForestClassifier
# 3. n_estimators, max_depth and min_samples_leaf
