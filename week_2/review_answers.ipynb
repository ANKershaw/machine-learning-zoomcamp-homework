# %%
## Review Answers

# %% [markdown]
# ### Pandas
#
# 1. df.columns.str.lower().str.replace(' ', '_') You can chain str. functions
# 2. list(df.dtypes[df.dtypes == 'object'].index)
# 3. df[col].nunique()
# 4. df.isnull() and df.isnull().sum() for the count
# 5. df.reset_index(drop=True)
# 6. df.copy()
#
#
# ### Numpy
#
# 1. np.column_stack([first, second]).

# %% [markdown]
# ### Plotting
#
# 1. sns.histplot(column, bins=50)
# 2. Seaborn is built on matplotlib. import matplotlib.pyplot as plt; import seaborn as sns
#
#
# ### Log Distribution
#
# 1. If there is data with a long tail, which is not suitable for ML, a log function will remove the tail.
# 2. If there are any 0 values, applying log will fail.
# 3. np.log
# 4. np.log1p. It adds 1 to all values performing doing the log.
# 5. np.log: use when x is expected to be significantly greater than zero and not in the immediate vicinity of 1. np.log1p: use when x can be very small (close to zero).
# 6. np.exp(value) - 1 or use np.expm1(value)

# %% [markdown]
# ### Validation Framework
#
# 1. Train (60%), Validate (20%), Test (20%)
# 2. Rarely
# 3. Create a list whose range is the length of the dataset. Shuffle this list (with or without a seed), and create the Train, Validate, and Test datasets using this shuffled index.
# 4. idx = np.arange(n) to get the range. np.random.seed(2) to set the seed. np.random.shuffle(idx) to shuffle the range. df.iloc[idx[n_train:]] to take the shuffled list's indices and select data

# %% [markdown]
# ### Linear Regression
#
# 1. Split the dataset into train, val, test. Use test to perform linear regression. Use the weights (w0, w) from performing linear regression on the validate dataset. Compare the predicted values generated by using the weights with the validate dataset to the known y values of the dataset and find the mean squared error to determine how effective the linear regression was.
# 2. A way to calculate the accuracy of the regression by squaring and summing the residuals of the data.
