# %%
from IPython.display import Image

# %% [markdown]
# ## Accuracy and Dummy Model
#
# 1. Define accuracy as a fraction
# 2. Explain what a threshold is
# 3. Logistic regression tries to make the threshold at _____ the best one
# 4. What package is used to calculate the accuracy score?
# 5. What is a dummy model?
# 6. Describe class imbalance.
# 7. Why is accuracy misleading when there is a class imbalance? What should be looked at instead?
#
# ## Confusion Table, Precision and Recall
#
# 1. A confusion table shows 4 results of an ML model. What are they?
# 2. Define precision and provide the fraction for it.
# 3. Define recall and provide a fraction for it.
# 4. TPR is also known as ______
# 5. FPR is also known as ______
#
# ## ROC Curve
#
# 1. ROC curve is used to evaluate the performance of a __________ classification model.
# 2. ROC curves involve the ___ and ___ rates.
# 3. TPR is the same as ________
# 4. An ROC curve shows the TPR and FPR for all possible _______
# 5. On a ROC curve, we want ____ to be as low as possible, and for ___ to be around 1
# 6. A ROC curve for a random model will look like ___ lines.
# 7. Explain what the black, blue, and yellow lines are in the diagram below and how they relate to each other.
# 8. ROC stands for _____ _____ _______
# 9. ROC curves are useful for ______
# 10. The shape of a 'good' ROC curve will look like what?
# 11. What package is used to plot a ROC curve?

# %%
Image(filename='./assets/image1.png')

# %% [markdown]
# ## ROC AUC
#
# 1. What is the ROC AUC curve a measurement of
# 2. The ROC curve has ___ on the x axis and ____ on the y axis
# 3. The AUC for our models should be between _____ and ______
# 4. How do you calculate ROC AUC with a package
# 5. AUC tells us what about the probability of a randomly selected sample?

# %% [markdown]
# ## Cross-Validation
#
# 1. The full train dataset consists of the ____ and ____ datasets
# 2. Explain how cross-validation uses all parts of the data set, and in what orders
# 3. The three parts (cells) are called ______
# 4. The multiple AUC scores from cross-validation will be used to determine the _____ and ______ _________ of AUC scores
# 5. The standard deviation shows how _____ the model is
# 6. What package do we use for KFold
# 7. Explain where kFold and cross-validation show up in the series of steps used to perform binary classification
