# %%
# Review Questions

# %% [markdown]
# ## Python
#
# 1. How do you create a dictionary from two lists?
#
# ## Pandas
#
# 1. How do you delete a column from a dataframe?
# 2. How do you get a count of null values in a dataframe?
# 3. How do you get counts of values in a column of a dataframe?
# 4. How do you get the percentages of the values in a column of a dataframe?
# 5. How do you display the dtypes of the values in a dataframe?
# 6. How do you display the number of unique values in a column of a dataframe?
# 7. How do you get the mean of a column, grouped by the unique values in the column?
# 8. How do you get the correlation coefficient between two variables?
# 9. How do you convert a column to numeric while dealing with errors?
# 10. How do you change yes/no values in a column to 0/1?
# 11. How do you perform multiple aggregate functions (mean, max, min) on a dataset simultaneously?
#
# ## Jupyter Notebook
#
# 1. How do you display more than one value in a cell?
# 2. Jupyter will not display the last data object in the cell if that object is in a _________.
#
#
# ## Scikit-Learn
#
# 1. What function can you use to split the dataset into  train/validate/test datasets?
# 2. What are the ratios for each of these: train/validate/test
# 3. What function do you use for mutual information? How do you import it?
# 4. What package do you import to perform one-hot encoding?
# 5. What are the steps to perform one-hot encoding on a dataset?
# 6. Explain the sparse=T/F option in the DictVectorizer.
# 7. What package do you import for linear regression?
# 8. What package do you import for logistic regression?
# 9. What are the steps for performing linear regression on a dataset that is already one-hot encoded?
#
#
# ## Logistic Regression
#
# ### Feature Importance
#
# 1. Explain churn rate
# 2. Explain risk ratio
# 3. If a risk ratio is greater than 1 is a customer more or less likely to churn?
#
#
# ### Mutual Information and Correlation
#
# 1. Explain the concept of mutual information
# 2. Mutual information comes from _________, which is the mathematical study of information.
# 3. How do you use python to determine mutual information?
# 4. How do you interpret a mutual information score? Is a score of .3 better or worse than .7?
# 5. How can you use Mutual Information to select variables to train a logistic regression model?
# 6. What is a correlation coefficient?
# 7. What is the symbol for correlation coefficient?
# 8. What's the range for the correlation coefficient?
# 9. What is a positive correlation? A negative correlation?
# 10. What are the ranges for low, moderate, and high correlation?
# 11. X needs to be a ______ number and Y needs to be a ______ number for correlation
# 12. What does a correlation coefficient of 0 represent?
# 13. How do you use python to find the correlation coefficient?
# 14. How do you interpret negative coefficients?
#
# ### One-Hot Encoding
#
# 1. What python package do you use to perform one-hot encoding?
# 2. Explain the concept of one-hot encoding.
# 3. Explain the steps of implementing one-hot encoding using the python package.
#
#
# ### Logistic Regression
#
# 1. Logistic regression uses which library?
# 2. Logistic regression is a ______ model
# 3. Explain the general steps used to perform logistic regression.
# 4. What is the difference between hard and soft predictions?
# 5. How do you get the hard and soft predictions out of the model?
# 6. How do you check the accuracy of the model?
# 7. When do you use fit_transform vs fit for the DictVectorizer?
#
# ## Logistic vs Linear Regression
#
# 1. Logistic Regression is a type of _____ machine learning that deals with the _______ of ______ classes.
# 2. Logistic Regression outputs terms between __ and __
# 3. Logistic Regression utilizes the _____ function to output terms within the probability range.
# 4. Explain the difference between logistic and linear regression results.
